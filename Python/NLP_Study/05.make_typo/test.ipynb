# %%
CHO = (
    'ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅃ', 'ㅅ',
    'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ'
)

JUNG = (
    'ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ', 'ㅖ', 'ㅗ', 'ㅘ',
    'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ', 'ㅣ'
)

JONG = (
    '', 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄹ', 'ㄺ',
    'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ',
    'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ'
)

FIRST_HANGUL_UNICODE = 0xAC00  # '가'
LAST_HANGUL_UNICODE = 0xD7A3  # '힣'
DEFAULT_COMPOSE_CODE = 'ᴥ'

# EOJEOL_TYPO = {'완전':'오나전', '뭘': '무러', '했는데':'햇는ㄷ', '처럼':'철머'}
TYPO = {
    'ㄱ' : ['ㅅ', 'ㄷ', 'ㄹ'], 'ㄲ' : ['ㄱ', 'ㅅ', 'ㅆ'], 'ㅂ' : ['ㅈ', 'ㅁ'], 'ㅃ' : ['ㅂ', 'ㅈ', 'ㅉ', 'ㅁ'], 'ㅈ' : ['ㅂ', 'ㄷ'], 'ㅉ' : ['ㅈ', 'ㅃ', 'ㄷ', 'ㄸ', 'ㅂ', 'ㄴ'],
    'ㄷ' : ['', 'ㅈ', 'ㄱ'], 'ㄸ' : ['ㄷ', 'ㄱ', 'ㄲ'], 'ㅅ': ['ㄱ', 'ㅎ'], 'ㅆ' : ['ㅅ', 'ㄱ', 'ㄲ', 'ㅎ'],
    'ㅁ' : ['ㅂ','ㄴ','ㅋ'], 'ㄴ' : ['ㅈ', 'ㅁ', 'ㅇ'], 'ㅇ' : ['ㄷ', '', 'ㄹ', 'ㄴ'], 'ㄹ' : ['ㅎ', 'ㄱ'], 'ㅎ' : ['ㄹ', 'ㅗ'],
    'ㅋ' : ['ㅁ', 'ㅌ'], 'ㅌ' : ['ㅋ', 'ㅇ', 'ㅊ'], 'ㅊ' : ['ㅍ', 'ㅌ', 'ㅇ'], 'ㅍ' : ['ㅠ', 'ㅊ', 'ㅎ'],
    'ㅛ' : ['ㅕ', 'ㅗ'], 'ㅕ' : ['ㅛ', 'ㅑ', 'ㅓ'], 'ㅑ' : ['ㅕ', 'ㅐ', 'ㅏ'], 'ㅐ' : ['ㅑ', 'ㅔ', 'ㅒ'], 'ㅒ' : ['ㅐ', 'ㅖ', 'ㅔ'], 'ㅔ' : ['', 'ㅖ', 'ㅐ', 'ㅒ'], 'ㅖ' : ['ㅔ', 'ㅖ', 'ㅐ'],
    'ㅗ' : ['ㅓ', 'ㅛ', 'ㅜ'], 'ㅓ' : ['ㅕ', 'ㅗ', 'ㅏ'], 'ㅏ' : ['ㅓ', 'ㅑ', 'ㅣ'], 'ㅣ' : ['', 'ㅏ'], 'ㅠ' : ['ㅜ','ㅍ'], 'ㅜ' : ['ㅠ', 'ㅡ'], 'ㅡ' : ['', 'ㅜ'],
    'ㄳ' : ['ㄱ', 'ㅅ'], 'ㄵ' : ['ㄴ', 'ㅈ'], 'ㄶ' : ['ㄴ', 'ㅎ'], 'ㄺ' : ['ㄹ', 'ㄱ'], 'ㄻ' : ['ㄹ', 'ㅁ'], 'ㄼ' : ['ㄹ', 'ㅂ'],
    'ㄽ' : ['ㄹ', 'ㅅ'], 'ㄾ' : ['ㄹ', 'ㅌ'], 'ㄿ' : ['ㄹ', 'ㅍ'], 'ㅀ' : ['ㄹ', 'ㅎ'], 'ㅄ' : ['ㅂ', 'ㅅ'],
    'ㅘ' : ['ㅗ', 'ㅏ'], 'ㅙ' : ['ㅗ', 'ㅐ', 'ㅚ'], 'ㅚ' : ['ㅗ', 'ㅣ', 'ㅙ'], 'ㅝ' : [ 'ㅜ', 'ㅓ'], 'ㅞ' : ['ㅜ', 'ㅔ'], 'ㅟ' : ['ㅜ', 'ㅣ'], 'ㅢ' : ['ㅡ', 'ㅣ']
        }

ssang_jaeum = ('ㄲ', 'ㄸ', 'ㅃ', 'ㅆ', 'ㅉ')

ggub_jong = {'ㄳ' : ('ㄱ', 'ㅅ'), 'ㄵ' : ('ㄴ', 'ㅈ'), 'ㄶ' : ('ㄴ', 'ㅎ'), 'ㄺ' : ('ㄹ', 'ㄱ'), 'ㄻ' : ('ㄹ', 'ㅁ'), 'ㄼ' : ('ㄹ', 'ㅂ'),
             'ㄽ' : ('ㄹ', 'ㅅ'), 'ㄾ' : ('ㄹ', 'ㅌ'), 'ㄿ' : ('ㄹ', 'ㅍ'), 'ㅀ' : ('ㄹ', 'ㅎ'), 'ㅄ' : ('ㅂ', 'ㅅ')}

ggub_jung = { 'ㅘ' : ('ㅗ', 'ㅏ'), 'ㅙ' : ('ㅗ', 'ㅐ'), 'ㅚ' : ('ㅗ', 'ㅣ'), 'ㅝ' : ('ㅜ', 'ㅓ'), 'ㅞ' : ('ㅜ', 'ㅔ'), 'ㅟ' : ('ㅜ', 'ㅣ'), 'ㅢ' : ('ㅡ', 'ㅣ')}

reversed_ggub_jong = dict(map(reversed, ggub_jong.items()))

reversed_ggub_jung = dict(map(reversed, ggub_jung.items()))

# %%
import re

def divide_jamo(emjeol):
    if re.match(r'[ㄱ_ㅎ|가-힣]', emjeol):
        chosung_idx, junsung_idx, jongsung_idx = get_unicode_number(emjeol)
        return CHO[chosung_idx] + JUNG[junsung_idx] + JONG[jongsung_idx]

    else : 
        return emjeol
    
def get_unicode_number(emjeol):
    emjeol_code = ord(emjeol)
    chosung_index = int((emjeol_code - 44032) / 588)
    jungsung_index = int((emjeol_code - 44032 - (chosung_index * 588)) / 28)
    jongsung_index = int((emjeol_code - 44032 - (chosung_index * 588) - (jungsung_index * 28)))
    return chosung_index, jungsung_index, jongsung_index

def get_hangeul_unicode(chosung_index, jungsung_index, jongsung_index):
    return((chosung_index * 588) + (jungsung_index * 28) + (jongsung_index)) + 44032

# %%
import random

def typo_change_jamo(jamo, convert):
    for i, x in enumerate(jamo):
        if random.random() > 0.9:
            idx = random.randrange(0, len(TYPO[x]))
            jamo = jamo[:i] + TYPO[x][idx] + jamo[i+1:]
            convert = False
    return jamo, convert
        
def typo_position_convert(jamo, convert):
    if random.random() > 0.9:
        idx = random.randrange(0, len(jamo)-1)
        if jamo[idx+1] in ggub_jong:
            jamo = jamo[:idx] + ggub_jong[jamo[idx+1]][0] + jamo[idx] + ggub_jong[jamo[idx+1]][1]
        else :
            jamo = jamo[:idx] + jamo[idx+1] + jamo[idx]
        convert = False
    return jamo, convert

# %%
import random

test_txt = '학교에는'

while True:
    cnt = 0
    emjeol_list = []
    for emjeol in test_txt:
        jamo = divide_jamo(emjeol)
        for i, x in enumerate(jamo):
            if random.random() >= 0.9:
                idx = random.randrange(0,len(TYPO[x]))
                jamo = jamo[:i] + TYPO[x][idx] + jamo[i+1:]
                cnt += 1
        emjeol_list.append(jamo)
    if cnt:
        break
typo_txt = ''
for emjeol in emjeol_list:
    jongsung_index = 0
    try:
        chosung_index = CHO.index(emjeol[0])
        jungsung_index = JUNG.index(emjeol[1])
        jongsung_index = JONG.index(emjeol[2])
    except:
        pass
    typo_txt += chr(get_hangeul_unicode(chosung_index, jungsung_index, jongsung_index))

typo_txt
# Out:
# '학교애는'

# %%
import random

test_txt = '학교에는'

while True:
    cnt = 0
    emjeol_list = []
    for emjeol in test_txt:
        jamo = divide_jamo(emjeol)
        for i, x in enumerate(jamo):
            if random.random() >= 0.9:
                idx = random.randrange(0,len(TYPO[x]))
                jamo = jamo[:i] + TYPO[x][idx] + jamo[i+1:]
                cnt += 1
        emjeol_list.append(jamo)
    if cnt:
        break

# emjeol_jamo = DEFAULT_COMPOSE_CODE.join(emjeol_list)
# emjeol_jamo

emjeol_list
# Out:
# ['ㅎㅏㄱ', 'ㄱㅛ', 'ㅇㅔ', 'ㄴㅡㅁ']

# %%
typo_jamo = 'ㅎㅏㄱᴥㄱㅛᴥㅔᴥㄴㅡㄴ'

# %%
test_txt = '삶았다'

cnt = 0
while True:
    emjeol_list = []
    for emjeol in test_txt:
        jamo = divide_jamo(emjeol)
        convert = True
        if convert:
            jamo, convert = typo_change_jamo(jamo, convert)
            cnt += 1
        if convert:
            jamo, convert = typo_position_convert(jamo, convert)
            cnt += 1
        emjeol_list.append(jamo)
    if cnt :
        break
print(DEFAULT_COMPOSE_CODE.join(emjeol_list))
# Out:
# ㅅㅏㅁᴥㅇㅏㅆᴥㅈㅏ

# %%
emjeol_list = ['ㄱㄱㅏ', 'ㅅㅏㄻ', 'ㅏㅆㅏ', 'ㅁㅁㅏ', 'ㅇ', 'ㅇㅗ', 'ㄴㄹ', 'ㅣ']

converted_list = []
for idx, emjeol_jamo in enumerate(emjeol_list): # 음절 자모를 입력받았을 때,

    if len(emjeol_jamo) == 3: # 음절 자모의 길이가 3이라면
        x, y, z = emjeol_jamo

        if (x in CHO) and (y in JUNG) and (z in JONG): # x, y, z가 초중종에 적절하게 있는 경우
            converted_list.append(x+y+z)

        elif x in JONG: # x가 종성(ㄱ, ㄻ)인 경우
            if y in JONG: # Y가 종성(ㄱ, ㄻ)인 경우
                if idx : # 첫 번째 음절이 아닐 때
                    if (converted_list[-1][-1] in JUNG) and (len(converted_list[-1]) > 1):
                        converted_list[-1] += x
                # 이전 음절의 마지막 자모가 중성이거나 첫 음절일 경우
                    else:
                        converted_list.append(x)
                else :
                    converted_list.append(x)
                
                if z in JONG: # z가 종성(ㄱ, ㄻ)인 경우
                    converted_list.append(y); converted_list.append(z)
                else: # z가 중성(ㅏ)인 경우
                    if y in CHO: # y가 초성, z가 중성인 경우
                        converted_list.append(y + z)
                    else : # y가 곁 받침, z가 중성인 경우
                        y1, y2 = ggub_jong[y]
                        converted_list.append(y1); converted_list.append(y2 + z)

            else: # y가 중성(ㅏ)인 경우
                # 가 z 중성(ㅏ)인 경우
                if x in CHO:
                    converted_list.append(x+y); converted_list.append(z)
                else :
                    x1, x2 = ggub_jong[x]
                    if idx: # 첫 음절이 아닐 때,
                        if (converted_list[-1][-1] in JUNG) and (len(converted_list[-1]) > 1):
                            converted_list[-1] += x1
                        else:
                            converted_list.append(x1)
                    else : # 첫 음절일 때
                        converted_list.append(x1)
                    converted_list.append(x2 + y); converted_list(z)

        else: # x 가 중성(ㅏ)인 경우
            if idx: # 첫 번째 음절이 아닌 경우
                if converted_list[-1][-1] in JONG: # 이전 음절의 마지막이 종성일 때,
                    h = converted_list[-1][-1]
                    if (h in CHO) :
                        if len(h) == 1: # 이
                            converted_list[-1] += x
                        else :
                            converted_list.append(h+x)
                            converted_list[-2] = converted_list[-2][:-1]
                    else: # h가 겹받침(ㄺ)
                        h1, h2 = ggub_jong[h]
                        converted_list[-1] = converted_list[-1][:-1] + h1
                        converted_list.append(h2 + x)

                else : # 이전 음절의 마지막이 중성일 때
                    converted_list.append(x)

            else : # 첫 번째 음절인 경우
                converted_list.append(x)

            # y z만 탐색
            if (y in CHO) and (z in JUNG):
                converted_list.append(y + z)

            elif y in JONG: # y가 종성일 때(ㄱ, ㄺ)
                if z in JONG:
                    if (converted_list[-1][-1] in JUNG) and ((converted_list[-1]) > 1):

                        if y in CHO:
                            converted_list[-1] += y
                        else: # y가 겹받침
                            y1, y2 = ggub_jong[y]
                            converted_list[-1] += y1
                            converted_list.append(y2)
                    else:
                        converted_list.append(y)
                    converted_list.append(z)

                else: # z가 중성일 때 (ㅏ)
                    # y가 겹받침, z가 중성
                    y1, y2 = ggub_jong[y]
                    if (converted_list[-1][-1] in JUNG) and ((converted_list[-1]) > 1):
                        converted_list[-1] += y1
                    else:
                        converted_list.append(y1)
                    converted_list.append(y2)
            else: # y가 중성일 때 (ㅏ)
                if converted_list[-1][-1] in JONG:
                    h = converted_list[-1][-1]
                    if h in CHO: # h가 초성일 때
                        if len(converted_list[-1]) == 1:
                            converted_list[-1] += y
                        else :
                            converted_list.append(h+y)
                            converted_list[-2] = converted_list[-2][:-1]
                    else: # h가 겹받침일 때
                        h1, h2 = ggub_jong[h]
                        converted_list[-1] = converted_list[-1][:-1] + h1
                        converted_list.append(h2 + y)

                else: # 앞 음절의 마지막이 종성일 때 ㅏ
                    converted_list.append(y)
                converted_list.append(z)
    

    elif len(emjeol_jamo) == 2: # 음절 자모의 길이가 2라면

        x, y = emjeol_jamo
        if (x in CHO) and (y in JUNG): # 정상
            converted_list.append(x + y)

        elif x in JONG: # x가 겹받침일 때 (ㄺ)

            if y in JONG: # y가 종성일 때 (ㄱ, ㄺ)
                if idx: # 첫 음절이 아닐 때
                    if (converted_list[-1][-1] in JUNG) and (len(converted_list[-1]) > 1) :
                        converted_list[-1] += x
                else: # 첫 음절일 때
                    converted_list.append(x)
                converted_list.append(y)

            else: # y가 중성일 때 (ㅏ)
                x1, x2 = ggub_jong[x]
                if (converted_list[-1][-1] in JUNG) and (len(converted_list[-1]) > 1) :
                    converted_list[-1] += x1
                else :
                    converted_list.append(x1)
                converted_list.append(x2 + y)

        else: # x 가 종성일 때 (ㅏ)

            if y in JONG: # y가 종성일 때 (ㄱ, ㄺ)
                if idx: # 첫 음절이 아닐 때
                    h = converted_list[-1][-1]
                    if (h in JONG): # 이전 마지막 자모가 종성일 때 (ㄹ ㄺ)
                        if h in CHO: # 이전 마지막 자모가 초성일 때 (ㄱ, ㅆ)
                            converted_list.append(h+x+y)
                            converted_list[-2] = converted_list[-2][:-1]
                        else: # 이전 마지막 자모가 겹 받침일 때
                            h1, h2 = ggub_jong[h]
                            converted_list[-1] = converted_list[-1][:-1] + h1
                            converted_list.append(h2 + x + y)
                    else : # 이전 마지막 자모가 중성일 때 (ㅏ)
                        converted_list.append(x); converted_list.append(y)
                    
                else: # 첫 음절일때
                    converted_list.append(x); converted_list.append(y)

    elif len(emjeol_jamo) == 1: # 음절 자모의 길이가 1이라면
        x = emjeol_jamo
        if idx: # 첫 번째 음절이 아닐 때
            if x in JONG: # x가 종성일 때 (ㄱ, ㄺ)
                if (converted_list[-1][-1] in JUNG) and (len(converted_list[-1]) > 1):
                    if x in CHO: # x가 초성일 때
                        converted_list[-1] += x
                    else : # x가 겹 받침일 때
                        x1, x2 = ggub_jong(x)
                        converted_list[-1] += x1
                        converted_list.append(x2)
                else: # 이전 음절 마지막 자모가 종성이거나 중성인데 1개일 때
                    converted_list.append(x)

            else: # x가 중성일 때 (ㅏ)

                h = converted_list[-1][-1]
                if h in JONG:
                    if h in CHO: # 이전 자모가 초성일 때
                        if len(converted_list[-1]) == 1:
                            converted_list[-1] += x
                        else:
                            converted_list.append(h+x)
                            converted_list[-2] = converted_list[-2][:-1]
                    else: # 이전 자모가 겹 받침일 때
                        h1, h2 = ggub_jong[h]
                        converted_list[-1] = converted_list[-1][:-1] + h1
                        converted_list.append(h2 + x)
                    
                else : # 이전 음절의 마지막 자모가 중성일 때 (ㅏ)
                    converted_list.append(x)

        else: # 첫 번째 음절일 때
            converted_list.append(x)
    
    else : # 음절 자모의 길이가 4일 때
        x, y, z, r = emjeol_jamo



            
print(emjeol_list)
print(converted_list)
ㄱ가살마쌈망온리
# Out:
# ['ㄱㄱㅏ', 'ㅅㅏㄻ', 'ㅏㅆㅏ', 'ㅁㅁㅏ', 'ㅇ', 'ㅇㅗ', 'ㄴㄹ', 'ㅣ']
# ['ㄱ', 'ㄱㅏ', 'ㅅㅏㄹ', 'ㅁㅏ', 'ㅆㅏㅁ', 'ㅁㅏㅇ', 'ㅇㅗㄴ', 'ㄹㅣ']

# %%
ㅗ / ㄱ ㅏ/ ㅅ ㅏ ㄹ /ㅁ ㅜ ㅇ ㅔ / ㅆ ㅏ ㅁ /ㅁ ㅗ ㅐ ㅇ /ㅇ ㅗ ㄹ ㄱ / ㄹ ㅣ

# %% [markdown]
# 겹받침 겹모음.... 만들기 추가

# %% [markdown]
# 새 노트

# %%
emjeol_list = ['ㄱㄱㅏ', 'ㅅㅏㄻ', 'ㅏㅆㅏ', 'ㅁㅁㅏ', 'ㅇ', 'ㅇㅗ', 'ㄴㄹ', 'ㅣ']

converted_list = ''

emjeol_jamo = ''.join(emjeol_list)
print(emjeol_jamo)

while emjeol_jamo:

    emjeol_idx = len(emjeol_jamo)-1

    for i in reversed(range(emjeol_idx)):

        if emjeol_jamo[i] in JUNG: # 뒤에서 첫 번째로 모음인 인덱스
            print('맨 뒤의 모음:',emjeol_jamo[i])
            

            '''
                i 앞이 자음인지 모음인지 확인
                i는 중성(ㅏ)
            '''
            if emjeol_jamo[i-1] in JUNG: 
                # i 앞이 중성일 때(ㅏ)
                jung1, jung2 = emjeol_jamo[i-1:i+1]
                
                if (jung1, jung2) in reversed_ggub_jung: # i-1, i의 모음 합쳐서 이중모음이 될 때 (ㅙ)
                    emjeol_jamo = emjeol_jamo[:i-1] + reversed_ggub_jung[(jung1, jung2)] + emjeol_jamo[i+1:]
                    i -= 1

                    if emjeol_jamo[i-1] in JUNG: # 수정한 i 앞이 중성일 때(ㅏ)
                        first_idx = i

                    else: # 수정한 i 앞이 종성일 때
                        if emjeol_jamo[i-1] in CHO: # i 앞이 초성일 때
                            first_idx  = i-1

                        else : # i 앞이 겹받침일 때
                            jong1, jong2 = ggub_jong
                            emjeol_jamo = emjeol_jamo[:i-1] + jong1, jong2 + emjeol_jamo[i+1:]
                            first_idx = i

                else: # i 앞이 겹 받침이 되지 않는 중성일 때(ㅏ, ㅏ)
                    first_idx = i
                    '''
                        그 이후를 봐야하는 곳임.
                        def 다 자음일때
                    '''


            else: 
                # i 앞이 종성일 때 (ㄱ, ㄲ, ㄺ)
                if emjeol_jamo[i-1] in CHO: # i 앞이 쌍자음 일 때
                    first_idx = i-1

                else: # i 앞이 겹받침일 때
                    jong1, jong2 = ggub_jong[emjeol_jamo[i-1]]
                    emjeol_jamo = emjeol_jamo[:i-1] + jong1 + jong2 + emjeol_jamo[i+1:]
                    first_idx = i

                




            # i 뒤의 자음
            if i == emjeol_idx: # i가 마지막 인덱스일 때
                last_idx = i
                
            elif i == emjeol_idx-1: # i뒤에 한 개 자음이 있을 때
                last_idx = i+1

            else: # i 뒤에 두 개 이상의 자음이 있을 때
                pass
        break
    break


# emjeol_list = ['ㄱㄱㅏ', 'ㅅㅏㄻ', 'ㅏㅆㅏ', 'ㅁㅁㅏ', 'ㅇ', 'ㅇㅗ', 'ㄴㄹ', 'ㅣ']
# print(emjeol_list)
# print(converted_list)
# Out:
#   Cell In[72], line 28
#     if
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# 2번째

# %%
emjeol_list = ['ㄱㄱㅏ', 'ㅅㅏㄻ', 'ㅏㅆㅏ', 'ㅁㅁㅏ', 'ㅇ', 'ㅇㅗ', 'ㄴㄹ', 'ㅣ']
emjeol_jamo = ''.join(emjeol_list)

converted_list = ''

while emjeol_jamo:

    emjeol_idx = len(emjeol_jamo)-1
    for i in reversed(range(emjeol_idx)):

        reamain_emjeol = ''

        '''
            i 뒤가 자음인지 모음인지 확인
            i는 중성(ㅏ)
        '''
        if i == emjeol_idx: # i가 마지막 인덱스인 경우
            last_idx = i
        
        elif emjeol_jamo[i+1]: # i 뒤에 자음(ㄱ, ㄲ, ㄺ) 이 있는 경우
            if (emjeol_jamo[i+1] in ssang_jaeum) or (emjeol_jamo[i+1] in ggub_jong): # i 뒤가 쌍자음이나 겹받침인 경우
                last_idx = i+1
            else: # i 뒤가 쌍자음이 아닌 초성인 경우
                if i+2 <= emjeol_idx : # i 뒤에 두 개상의 자음이 남아있는 경우
                    pass
                else: # i 뒤에 한 개의 자음만 있는 경우
                    pass

# %%
import random

random.randrange(2)
# Out:
# 1

# %%
test = 'ㅇㄳㅏ'
idx = 1
jong1, jong2 = ggub_jong[test[idx]]
test = test[:idx-1] + jong1 + jong2 + test[idx+1:]
test[idx]
# Out:
# 'ㅅ'
